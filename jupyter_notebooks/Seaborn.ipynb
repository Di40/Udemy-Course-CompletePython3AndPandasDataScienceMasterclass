# %% [markdown]
# # Seaborn

# %%
# %matplotlib inline
#%matplotlib notebook
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
df1 = sns.load_dataset('iris')
print(type(df1))
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Visualisations with Seaborn

# %%
df2 = sns.load_dataset('iris')
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.displot(df2['petal_length'], kind="hist")
plt.show()

# %%
sns.displot(df2['petal_length'], kind="kde")
plt.show()

# %%
sns.displot(df2['petal_length'], kde=True)
plt.show()

# %% [markdown]
# ## Plotting bivariate distribution

# %%
sns.jointplot(x='petal_length', y='petal_width', data=df2)
plt.show()

# %%
sns.jointplot(x='petal_length', y='petal_width', data=df2, kind='hex')
plt.show()

# %%
sns.set_style("ticks")
sns.pairplot(df2, hue='species', diag_kind='kde', kind='scatter', palette='husl')
plt.show()

# %%
plt.figure()
sns.stripplot(x='species', y='petal_length', data=df2)
plt.show()

# %%
plt.figure()
sns.stripplot(x='species', y='petal_length', data=df2, jitter=True)
plt.show()

# %%
plt.figure()
sns.swarmplot(x='species', y='petal_length', data=df2, size=3)
plt.show()

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
df3 = sns.load_dataset('tips')
df3.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Everything reminds me of her...

# %%
plt.figure()
sns.violinplot(x='day', y='total_bill', data=df3)
plt.show()

# %%
plt.figure()
sns.violinplot(x='day', y='total_bill', hue='sex', data=df3)
plt.show()

# %%
df4 = sns.load_dataset('titanic')
df4.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure()
sns.barplot(x='sex', y='survived', data=df4, hue='class')
plt.show()

# %%
plt.figure()
sns.countplot(x='class', data=df4, palette='Blues')
plt.show()

# %%
plt.figure()
sns.pointplot(x='sex', y='survived', data=df4, hue='class')
plt.show()

# %%
df5 = sns.load_dataset('iris')
df5.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure()
sns.boxplot(data=df5, orient='h') # default value for orient is v
plt.show()

# %%
df = sns.load_dataset('iris')
plt.figure(figsize=(5,6))
sns.regplot(x='sepal_length', y='petal_length', data=df5)
plt.show()

# %%
f, ax = plt.subplots(figsize=(5,6))
sns.regplot(x='sepal_length', y='petal_length', data=df5)
plt.show()

# %% [markdown]
# ## Regression Visualized

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='Set1')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')
plt.show()

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, row='sex')
plt.show()
